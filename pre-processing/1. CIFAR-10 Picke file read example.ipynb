# %% [markdown]
# # Pickle file read test
#
# This code is reading CIFAR-10 Python file.
# The file is encoded with cPikcle file format
# <br>
# This code will read one of the Pickle file and display the image with label & file name
# <br>
# You can download Pickefile from http://www.cs.toronto.edu/~kriz/cifar.html
# <p>
# Plz download <br>
# "CIFAR-10 python version	163 MB	c58f30108f718f92721af3b95e74349a"

# %%
# propery
PICKLE_FILE = '/Users/terrycho/dev/workspace/cifar-10/data/original/data_batch_1'

# %%
import cPickle
import numpy as np
import matplotlib.pyplot as plt

#for Python2
def unpickle(file):
    import cPickle
    with open(file, 'rb') as fo:
        dict = cPickle.load(fo)
    data = dict.get('data')
    labels = dict.get('labels') #narray
    filenames = dict.get('filenames')
    size = len(data)
    return size,data,labels,filenames

#decode picke file 
size,data,labels,filenames = unpickle(PICKLE_FILE)

for i in range(0,3):
    flat_image = data[i]
    label = labels[i]
    filename = filenames[i]
    
    R = flat_image[0:1024].reshape((32,32))
    G = flat_image[1024:2048].reshape((32,32))
    B = flat_image[2048:3072].reshape((32,32))
    img_array = np.dstack((R,G,B))
    plt.imshow(img_array)
    plt.show()
    print('Label :'+str(label)+' filename:'+filename)
# Out:
# Label :6 filename:leptodactylus_pentadactylus_s_000004.png
# Label :9 filename:camion_s_000148.png
# Label :9 filename:tipper_truck_s_001250.png

# %% [markdown]
# # Print labels
#
# CIFAR-10 dataset has 10 category. <br>
# To training machine learning model, it needs to check that do we need data shuffle.<Br>
# we can check this by checking "labels" array<br>
# as you can see, original data labels are already shuffled, So we don't need to shuffle

# %%
print labels
# Out:
# [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6, 4, 3, 6, 6, 2, 6, 3, 5, 4, 0, 0, 9, 1, 3, 4, 0, 3, 7, 3, 3, 5, 2, 2, 7, 1, 1, 1, 2, 2, 0, 9, 5, 7, 9, 2, 2, 5, 2, 4, 3, 1, 1, 8, 2, 1, 1, 4, 9, 7, 8, 5, 9, 6, 7, 3, 1, 9, 0, 3, 1, 3, 5, 4, 5, 7, 7, 4, 7, 9, 4, 2, 3, 8, 0, 1, 6, 1, 1, 4, 1, 8, 3, 9, 6, 6, 1, 8, 5, 2, 9, 9, 8, 1, 7, 7, 0, 0, 6, 9, 1, 2, 2, 9, 2, 6, 6, 1, 9, 5, 0, 4, 7, 6, 7, 1, 8, 1, 1, 2, 8, 1, 3, 3, 6, 2, 4, 9, 9, 5, 4, 3, 6, 7, 4, 6, 8, 5, 5, 4, 3, 1, 8, 4, 7, 6, 0, 9, 5, 1, 3, 8, 2, 7, 5, 3, 4, 1, 5, 7, 0, 4, 7, 5, 5, 1, 0, 9, 6, 9, 0, 8, 7, 8, 8, 2, 5, 2, 3, 5, 0, 6, 1, 9, 3, 6, 9, 1, 3, 9, 6, 6, 7, 1, 0, 9, 5, 8, 5, 2, 9, 0, 8, 8, 0, 6, 9, 1, 1, 6, 3, 7, 6, 6, 0, 6, 6, 1, 7, 1, 5, 8, 3, 6, 6, 8, 6, 8, 4, 6, 6, 1, 3, 8, 3, 4, 1, 7, 1, 3, 8, 5, 1, 1, 4, 0, 9, 3, 7, 4, 9, 9, 2, 4, 9, 9, 1, 0, 5, 9, 0, 8, 2, 1, 2, 0, 5, 6, 3, 2, 7, 8, 8, 6, 0, 7, 9, 4, 5, 6, 4, 2, 1, 1, 2, 1, 5, 9, 9, 0, 8, 4, 1, 1, 6, 3, 3, 9, 0, 7, 9, 7, 7, 9, 1, 5, 1, 6, 6, 8, 7, 1, 3, 0
# ...
